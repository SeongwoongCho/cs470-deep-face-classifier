# %%
# !python main.py --threads 5 --google true --naver false --full true --face false --no_gui true --limit 1000
# Out:
# Options - skip:True, threads:5, google:True, naver:False, full_resolution:True, face:False, no_gui:True, limit:1000
# 10 keywords found: ['강동원', '김희선', '엑소 시우민', '워너원 황민현', '유인영', '이나영', '이종석', '이준기', '한예슬', '한채영']
# Detected OS : Linux
# Detected OS : Linux
# Detected OS : Linux
# Detected OS : Linux
# Detected OS : Linux
# _________________________________
# Current web-browser version:	86.0.4240.198
# Current chrome-driver version:	85.0.4183.87
# ...
# Download correct version at "http://chromedriver.chromium.org/downloads" and place in "./chromedriver"
# _________________________________
# ...
# [Full Resolution Mode]
# _________________________________
# Current web-browser version:	86.0.4240.198
# Current chrome-driver version:	85.0.4183.87
# ...
# Download correct version at "http://chromedriver.chromium.org/downloads" and place in "./chromedriver"
# _________________________________
# ...
# [Full Resolution Mode]
# _________________________________
# Current web-browser version:	86.0.4240.198
# ...
